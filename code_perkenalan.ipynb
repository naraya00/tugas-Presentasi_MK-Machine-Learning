# %%
# Perkenalan
## Mata Kuliah Machine Learning

# %%
nama = "Rosa Helmalina Putri"
nim = "231001041"
mata_kuliah = "Machine Learning"

print("Perkenalan")
print("Nama :", nama)
print("NIM  :", nim)
print("Mata Kuliah :", mata_kuliah)
# Out:
# Perkenalan
# Nama : Rosa Helmalina Putri
# NIM  : 231001041
# Mata Kuliah : Machine Learning
